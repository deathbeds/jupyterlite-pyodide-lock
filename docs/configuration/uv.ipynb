# %% [markdown]
# # `jupyterlite-pyodide-lock-uv`

# %%
from importnb import Notebook

with Notebook():
    from core import config_table, markdown

UV = "jupyterlite_pyodide_lock_uv"

# %% [markdown]
# ## Lockers
#
# The `UvLocker` uses `uv pip compile`.

# %%
if __name__ == "__main__":
    display(markdown(config_table(f"{UV}.locker.UvLocker")))
